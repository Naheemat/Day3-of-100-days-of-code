# %%
print('''
  ___
            / _ \
           | / \ |
           | \_/ |
            \___/ ___
            _|_|_/[_]\__==_
           [---------------]
           | O   /---\     |
           |    |     |    |
           |     \___/     |
           [---------------]
                 [___]
                  | |\\
                  | | \\
                  [ ]  \\_
                 /|_|\  ( \
                //| |\\  \ \
               // | | \\  \ \
              //  |_|  \\  \_\
             //   | |   \\
            //\   | |   /\\
           //  \  | |  /  \\
          //    \ | | /    \\
         //      \|_|/      \\
        //        [_]        \\
       //          H          \\
      //           H           \\
     //            H            \\
    //             H             \\
   //              H              \\
  //                               \\
 //                                 \\
''')

print('You are in a mysterious enchanted forest, surrounded by towering trees. Which way do you want to go?')
print('On the right, there\'s a narrow path. It looks intriguing but also foreboding. \nAnd on the left, a hidden trail awaits.')

Reply1 = input('What\'s your instinct? ').lower()
if Reply1 == 'left':
    print('Do you want to swim across the mystical river or wait? ')
    
    Reply2 = input('The river has an enchanting allure, but waiting might unveil something unexpected. \nDo you want to wait or swim? ').lower()
    if Reply2 == 'wait':
        print('Good call! Patience pays off. Now, you are faced with three doors: blue, red, and yellow.')
        
        Reply3 = input(' Which door catches your eye? ').lower()
        if Reply3 == 'blue':
            print('It is a room full of snakes, Game Over!.')
        elif Reply3 == 'red':
            print('It is a room full of beasts, Game Over!')
        elif Reply3 == 'yellow':
            print('Yes! you made the right choice. \nBut wait, amidst the celebration, did glint catches your eye?.\n It\'s your camera.\nYou must have dropped it along the way.')
            print('''Indeed! With your camera in hand, you can create lasting memories and document the wonders you encounter.\n
                    Continue your adventure and explore the depths of this mystical forest and while capturing its secrets.''')
        else:
            print('You can only input Red, Blue or Yellow. ')
        
    else:
        print('Sorry dear, Game Over!.')
else:
    print('Oh no! It seems you\'ve fallen into a trap. Next time, go left instead. Game Over...')
